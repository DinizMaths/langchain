# %%
import os

from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from pinecone import Pinecone

# %%
PINECONE_API_KEY = os.environ.get("PINECONE_API_KEY")
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

# %%
pine = Pinecone(api_key=PINECONE_API_KEY)

# %%
pine.list_indexes()
# Out:
# {'indexes': []}

# %%
from pinecone import ServerlessSpec

# %%
index_name = "langchain"

if index_name not in pine.list_indexes().names():
    print(f"Creating index {index_name}")

    pine.create_index(
        name=index_name,
        dimension=1536,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1",
        ),
    )

    print(f"Index {index_name} created")
# Out:
# Creating index langchain
# Index langchain created

# %%
index = pine.Index(index_name)

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
import random

vectors = [[random.random() for _ in range(1536)] for v in range(5)]
ids = list("abcde")

index_name = "langchain"
index = pine.Index(index_name)

index.upsert(vectors=zip(ids, vectors))
# Out:
# {'upserted_count': 5}

# %%
index.upsert(vectors=[('c', [0.5] * 1536)])
# Out:
# {'upserted_count': 1}

# %%
index.fetch(ids=["a"]).vectors["a"].values
# Out:
# [0.23729898,
#  0.985395133,
#  0.263809741,
#  0.702729702,
#  0.953879118,
#  0.238443837,
#  0.527686477,
#  0.77764231,
#  0.951725543,
#  0.72390449,
#  0.529577076,
#  0.368944764,
#  0.992309153,
#  0.492987096,
#  0.497626811,
#  0.482107967,
#  0.552660227,
#  0.247973546,
#  0.281994313,
#  0.758099556,
#  0.0282133427,
#  0.504692495,
#  0.690535,
#  0.92677927,
#  0.346552938,
#  0.588260889,
#  0.563542426,
#  0.723368943,
#  0.380051196,
#  0.431026161,
#  0.544169545,
#  0.840601265,
#  0.9648453,
#  0.99228394,
#  0.756762326,
#  0.678016841,
#  0.104129888,
#  0.0409975462,
#  0.443414778,
#  0.463496923,
#  0.648556,
#  0.0366317853,
#  0.736634135,
#  0.797796488,
#  0.791157365,
#  0.625115454,
#  0.540475786,
#  0.505380809,
#  0.999245226,
#  0.544915318,
#  0.948356628,
#  0.259998828,
#  0.603539288,
#  0.481973171,
#  0.541835129,
#  0.296688557,
#  0.0364025459,
#  0.539036512,
#  0.987723053,
#  0.970428646,
#  0.566822529,
#  0.588276803,
#  0.115532376,
#  0.220133573,
#  0.932952702,
#  0.0213260688,
#  0.645722032,
#  0.186477363,
#  0.805423915,
#  0.173410341,
#  0.0966291,
#  0.440703064,
#  0.311690211,
#  0.154984191,
#  0.187228143,
#  0.582284033,
#  0.989195168,
#  0.851916552,
#  0.494230092,
#  0.714465499,
#  0.709216535,
#  0.241899326,
#  0.0127618276,
#  0.311329305,
#  0.0990761295,
#  0.68302381,
#  0.52246803,
#  0.475210071,
#  0.274815887,
#  0.22678569,
#  0.270145208,
#  0.613912463,
#  0.44042474,
#  0.331415951,
#  0.297554076,
#  0.695090413,
#  0.795432389,
#  0.381503075,
#  0.626376808,
#  0.177855745,
#  0.243883952,
#  0.0349602327,
#  0.292900592,
#  0.254602313,
#  0.629249513,
#  0.853237331,
#  0.0421889201,
#  0.374433756,
#  0.0681868419,
#  0.727606416,
#  0.888043463,
#  0.800819099,
#  0.0479337648,
#  0.673391521,
#  0.873204052,
#  0.563131452,
#  0.680634856,
#  0.524826586,
#  0.997095704,
#  0.546154261,
#  0.282440305,
#  0.810453117,
#  0.749477625,
#  0.646884799,
#  0.831808031,
#  0.0435124263,
#  0.0498739183,
#  0.139966249,
#  0.268838495,
#  0.755442917,
#  0.0356571339,
#  0.352175176,
#  0.480172247,
#  0.75225693,
#  0.444244713,
#  0.101353876,
#  0.155135915,
#  0.0122963367,
#  0.591541409,
#  0.853227437,
#  0.0503193848,
#  0.153106645,
#  0.631361842,
#  0.881314635,
#  0.353638172,
#  0.500633538,
#  0.00694191596,
#  0.356853753,
#  0.728746951,
#  0.406161606,
#  0.546199679,
#  0.122300737,
#  0.996181667,
#  0.491496414,
#  0.20762381,
#  0.658502221,
#  0.651925,
#  0.0416146,
#  0.408831835,
#  0.6178599,
#  0.0599111952,
#  0.183721334,
#  0.929958224,
#  0.498135775,
#  0.82358104,
#  0.0465554669,
#  0.813242316,
#  0.523485601,
#  0.341887116,
#  0.392339081,
#  0.788259566,
#  0.501620054,
#  0.439699471,
#  0.372570634,
#  0.214307219,
#  0.987085879,
#  0.323155135,
#  0.172660097,
#  0.126486644,
#  0.650087953,
#  0.241758615,
#  0.52021265,
#  0.649493158,
#  0.00167624967,
#  0.200125962,
#  0.544622242,
#  0.107320562,
#  0.647855,
#  0.300571799,
#  0.999599576,
#  0.466413736,
#  0.329160213,
#  0.591393173,
#  0.627543211,
#  0.5636549,
#  0.702572584,
#  0.587822735,
#  0.342775971,
#  0.678336442,
#  0.210614845,
#  0.759304821,
#  0.631983161,
#  0.424199224,
#  0.806946,
#  0.26407221,
#  0.732820868,
#  0.81928885,
#  0.0294658244,
#  0.739835203,
#  0.517876208,
#  0.326523721,
#  0.987179458,
#  0.102211684,
#  0.620523632,
#  0.354985654,
#  0.571608782,
#  0.725267828,
#  0.681330919,
#  0.38558194,
#  0.141489238,
#  0.351027459,
#  0.00903401,
#  0.361852109,
#  0.918367624,
#  0.579526126,
#  0.422652572,
#  0.521889031,
#  0.519441903,
#  0.238939375,
#  0.698857427,
#  0.550027728,
#  0.856185853,
#  0.44816336,
#  0.746178627,
#  0.444623,
#  0.810120344,
#  0.934211671,
#  0.3161816,
#  0.967767179,
#  0.349707067,
#  0.762910664,
#  0.814569592,
#  0.347831,
#  0.789497137,
#  0.879929125,
#  0.94973141,
#  0.191587955,
#  0.209687367,
#  0.962816238,
#  0.505535901,
#  0.291303247,
#  0.749255836,
#  0.486759216,
#  0.431407541,
#  0.219425082,
#  0.599622726,
#  0.0909609,
#  0.230200589,
#  0.95847106,
#  0.566093683,
#  0.558168411,
#  0.00798571482,
#  0.303864688,
#  0.182893023,
#  0.535451889,
#  0.115624994,
#  0.871762812,
#  0.32773903,
#  0.101003624,
#  0.306576282,
#  0.836213,
#  0.524218917,
#  0.319139868,
#  0.502876163,
#  0.416194499,
#  0.524423361,
#  0.55654484,
#  0.0325182192,
#  0.716597319,
#  0.0307718124,
#  0.56272018,
#  0.958417952,
#  0.0739012957,
#  0.290789217,
#  0.0875735655,
#  0.606739104,
#  0.667394817,
#  0.539919138,
#  0.00113768806,
#  0.86089009,
#  0.0502992272,
#  0.583004355,
#  0.758153439,
#  0.167289227,
#  0.647898793,
#  0.796828568,
#  0.330090463,
#  0.739594698,
#  0.753811777,
#  0.85174334,
#  0.702409208,
#  0.0253647398,
#  0.399587125,
#  0.0035408,
#  0.663899541,
#  0.795742095,
#  0.83056438,
#  0.038854789,
#  0.999345601,
#  0.360442072,
#  0.587420642,
#  0.294646263,
#  0.0764676929,
#  0.245624155,
#  0.659800708,
#  0.97376442,
#  0.82160008,
#  0.938586831,
#  0.0340948366,
#  0.667063117,
#  0.262123734,
#  0.456781536,
#  0.721333385,
#  0.560434699,
#  0.0215024464,
#  0.942325354,
#  0.461854607,
#  0.368184477,
#  0.618709326,
#  0.518197238,
#  0.310184121,
#  0.277831197,
#  0.265792191,
#  0.564069331,
#  0.999928117,
#  0.356894702,
#  0.315467447,
#  0.236318916,
#  0.454654217,
#  0.306442797,
#  0.789417922,
#  0.802576125,
#  0.377145737,
#  0.857154131,
#  0.967844903,
#  0.167561218,
#  0.891999066,
#  0.82685,
#  0.705221355,
#  0.834893167,
#  0.810533702,
#  0.37339738,
#  0.0765131339,
#  0.735341072,
#  0.543070912,
#  0.276953638,
#  0.655379832,
#  0.219151661,
#  0.236241117,
#  0.450115919,
#  0.553780615,
#  0.74628818,
#  0.909607053,
#  0.285800397,
#  0.036552906,
#  0.0712628439,
#  0.772053838,
#  0.4765279,
#  0.123304076,
#  0.57738781,
#  0.144878358,
#  0.790995061,
#  0.653452098,
#  0.441236,
#  0.126083896,
#  0.932253897,
#  0.753418148,
#  0.411614627,
#  0.180647776,
#  0.815449297,
#  0.274869025,
#  0.307807863,
#  0.471295208,
#  0.691928446,
#  0.281803191,
#  0.950345278,
#  0.0551122688,
#  0.261026889,
#  0.512036085,
#  0.474315375,
#  0.375138909,
#  0.124509506,
#  0.274637401,
#  0.373707831,
#  0.118872307,
#  0.988275468,
#  0.963275254,
#  0.423000783,
#  0.559221268,
#  0.135386944,
#  0.868862629,
#  0.491467357,
#  0.859311342,
#  0.786496699,
#  0.843475759,
#  0.296069533,
#  0.295655847,
#  0.406667918,
#  0.984292567,
#  0.908420801,
#  0.754108071,
#  0.84531337,
#  0.373326242,
#  0.441520751,
#  0.55180186,
#  0.603091121,
#  0.975820601,
#  0.508792639,
#  0.59503293,
#  0.254490644,
#  0.506831586,
#  0.400256753,
#  0.105499566,
#  0.19078216,
#  0.899187505,
#  0.37407738,
#  0.0890749,
#  0.609393,
#  0.840991259,
#  0.536741674,
#  0.442672342,
#  0.369674325,
#  0.577417374,
#  0.183533087,
#  0.53848505,
#  0.502387702,
#  0.47623542,
#  0.0466742627,
#  0.332546383,
#  0.279033393,
#  0.572606325,
#  0.135721251,
#  0.95505,
#  0.12410482,
#  0.374838889,
#  0.723090589,
#  0.569075942,
#  0.112109303,
#  0.754232645,
#  0.948293686,
#  0.263080627,
#  0.79246074,
#  0.361845404,
#  0.196624398,
#  0.231851101,
#  0.171140656,
#  0.504600048,
#  0.501263559,
#  0.42951721,
#  0.443292141,
#  0.635577559,
#  0.139085174,
#  0.528401732,
#  0.463301688,
#  0.815861762,
#  0.929800272,
#  0.437418193,
#  0.379860163,
#  0.806512,
#  0.387149066,
#  0.505920053,
#  0.802699625,
#  0.154760793,
#  0.759785712,
#  0.41448611,
#  0.703815579,
#  0.258910328,
#  0.548385441,
#  0.927507162,
#  0.111922339,
#  ...]

# %%
index.fetch(ids=["c"]).vectors["c"].values
# Out:
# [0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  ...]

# %%
index.delete(ids=["c"])
# Out:
# {}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 4}},
#  'total_vector_count': 4}

# %%
query_vector = [random.random() for _ in range(1536)]

# %%
index.query(
    vector=query_vector,
    top_k=2,
    include_values=False
)
# Out:
# {'matches': [{'id': 'e', 'score': 0.754713, 'values': []},
#              {'id': 'b', 'score': 0.749025643, 'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 5}}

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    length_function=len
)

# %%
import requests

url = "https://raw.githubusercontent.com/egodat/Churchill/master/We_shall_fight.txt"

response = requests.get(url)
churchill_speech = response.text

# %%
chunks = text_splitter.create_documents([churchill_speech])

for i in range(5):
    print(chunks[i].page_content)
# Out:
# From the moment that the French defenses at Sedan and on the Meuse were broken at the end of the
# at the end of the second week of May, only a rapid retreat to Amiens and the south could have saved
# could have saved the British and French Armies who had entered Belgium at the appeal of the Belgian
# of the Belgian King; but this strategic fact was not immediately realized. The French High Command
# French High Command hoped they would be able to close the gap, and the Armies of the north were

# %%
def print_embedding_cost(texts):
    import tiktoken

    enc = tiktoken.encoding_for_model("text-embedding-ada-002")
    total_tokens = sum([len(enc.encode(page.page_content)) for page in texts])

    print(f"Total tokens: {total_tokens}")
    print(f"Cost: {total_tokens / 1000 * 0.0004:.6f} USD")

# %%
print_embedding_cost(chunks)
# Out:
# Total tokens: 5389
# Cost: 0.002156 USD

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings(api_key=OPENAI_API_KEY)

# %%
vector = embeddings.embed_query(chunks[0].page_content)

print(vector)
# Out:
# [-0.010211220814272481, 0.0007125094909197949, -0.0004776955987905259, 0.014987327901661632, -0.011006106484375009, 0.03956763024139059, -0.025341219881993882, -0.04149709589848755, 0.011162365646627872, -0.03155083914733523, 0.01740595303980682, 0.02712121944361197, 0.011760228165898263, -0.024199846828225464, 0.0049425572467868325, 0.008166259052179365, -0.0014878625329100745, 0.024267784946545797, 0.006474580068832531, -0.030626868444720897, 0.0035532060564621853, -0.026672823019820456, -0.003593969346549537, 0.011692289116255368, 0.011508854892938887, -0.0030436638826324023, 0.004979923304995271, -0.044432058372712274, -0.01574824358128143, -0.003566793819824636, 0.0006110257159594685, -0.018656030063119968, -0.019919693219981084, -0.023235113999676985, -0.012860839093732533, -0.014538930546547557, 0.0016551621749004643, -0.011434121845199447, 0.013377174567166939, -0.0037706105030920365, 0.029268091177153267, -0.01493297684821183, 0.005071640882314793, 0.012894808152892697, -0.025558624095793094, 0.015707479592702158, 0.001320562890919685, -0.02729786153147703, -0.020028395326880687, -0.0017528243841391437, 0.01808534353623576, 0.015829769695794853, -0.030164884024736292, -0.01120992363330369, -0.019933281216174173, -0.03046381621569405, -0.030192060017122473, 0.018465799979061816, -0.008207022109436078, -0.025164579656773947, -0.00014596254730864182, 0.026835877111492427, -0.006440610544011085, -0.003184637247659959, -0.010238396806658664, -0.007011297536556575, 0.009946259545120012, 0.021292060346386928, -0.006270762919903849, -0.020979542021881206, 0.022283969167321595, 0.029295265306894323, 0.016726564406023006, 0.0007248234378468034, 0.023900914637267706, -0.02818106824551209, -0.006722556808404916, -0.014701983706896965, -0.009647328285484816, -0.003118396930371842, 0.011447709841392538, -0.03774686855383836, -0.05149770835970249, 0.018207633639328456, 0.026020610378422824, 0.01204557236066293, 0.007201526223630884, 0.0406546550356769, 0.012541525839807699, -0.02809954026835354, 0.02597984638984355, 0.027569617730048606, 0.0030096945906415962, 0.009368778088816695, -0.006447404076446349, -0.021332824334966204, -0.005835954026644147, 0.02284106769801271, 0.021957860983977652, 0.007160763166374173, -0.008757327573353213, -0.007432518899284468, -0.015096030008561237, -0.016699388413636822, -0.04527450296081319, -0.03492061004915837, 0.003638129635685162, 0.0008148425156421895, -0.01587053368437413, -0.005489465245994413, -0.005041068356541619, 0.02481129734368895, 0.01269099193528658, -0.019783815120695294, -0.01159038100745231, -0.01771847322695767, 0.00022610924213913535, 0.005241488506422028, -0.010591679119743663, -0.015911297672953403, 0.008077938939569398, 0.0392415257833369, 0.021550228548765413, -0.019525648780961937, 0.04255694470038768, 0.009823969442027316, -0.018289159753841877, 0.0024458013633620107, 0.008920381665025182, -0.01667221242125064, 0.009851144503090936, -0.013954656023470256, 0.0010946659466691516, -0.027420151634569727, -0.01653633432196485, 0.03793709677525139, -0.030273586131635898, -0.01261625888754714, -0.029295265306894323, -0.02194427298778456, 0.011087633530210994, 0.022650839476599682, -0.026876639237426576, -0.012099923414112732, 0.01808534353623576, 0.012786106045993093, -0.011053663539728266, 0.013152976355271183, -0.011284655749720568, -0.004371870254241342, 0.02165893065566502, -0.023819388522754285, 0.02063984584234417, 0.013424732553842758, 0.028806104894523538, -0.00129508586371892, -0.006990915542266938, 0.0028160686716883735, -0.006668205754955114, 0.0030657441436155353, -0.013119007296111018, 0.00342072495622467, 0.0030674426431396714, -0.006321717439966661, 0.01945770879999648, 0.01156320594638869, 0.0056695034015851855, 0.030219236009508658, -0.02663205903124118, -0.02525969376748046, 0.010496564077714585, 0.008845648617285743, 0.004799885149404499, 0.03652396752291139, -0.010442213024264782, 0.03774686855383836, 0.010571297125454024, 0.00013141936341194937, -0.02540915986 ...

# %% [markdown]
# # Insert Embeddings in Pinecone Index

# %%
import pinecone

from langchain_community.vectorstores import Pinecone

# %%
pine = pinecone.Pinecone(api_key=PINECONE_API_KEY)

# %%
for index in pine.list_indexes().names():
    print(f"Deleting index {index}")
    pine.delete_index(index)
    print(f"Index {index} deleted")
# Out:
# Deleting index churchill-speech
# Index churchill-speech deleted

# %%
index_name = "churchill-speech"

if index_name not in pine.list_indexes().names():
    print(f"Creating index {index_name}")

    pine.create_index(
        name=index_name,
        dimension=1536,
        metric="cosine",
        spec=pinecone.ServerlessSpec(
            cloud="aws",
            region="us-east-1",
        ),
    )

    print(f"Index {index_name} created")
# Out:
# Creating index churchill-speech
# Index churchill-speech created

# %%
import requests

url = "https://raw.githubusercontent.com/egodat/Churchill/master/We_shall_fight.txt"

response = requests.get(url)
churchill_speech = response.text
chunks = text_splitter.create_documents([churchill_speech])

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings(api_key=OPENAI_API_KEY)

# %%
vector_store = Pinecone.from_documents(
    chunks,
    embeddings,
    index_name=index_name
)

# %%
vector_store = Pinecone.from_existing_index(
    index_name=index_name,
    embedding=embeddings
)

# %% [markdown]
# # Similarity Search
